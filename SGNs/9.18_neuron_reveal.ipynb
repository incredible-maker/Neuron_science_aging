# %%
import scanpy as sc
# Out:
# [Executed on 2023-09-20 14:50:02.681365]

# %%
cell_type_markers = {
    "Immune cells": [
        "Cd74", "H2-Ab1", "H2-Aa", "H2-Eb1", "Fxyd5", "Lyz2", "lfitm3", "Ms4a6c",
        "lfitm2Cybb", "Plbd1", "ApoeCd52", "lqgap1", "Lgals3"
    ],
    "Macrophage": [
        "Tyrobp", "Fcer1g", "Ctss", "Cst3", "Laptm5", "Cd68", "H2-DMb1", "Ctsz",
        "Ftl1", "Aif1", "Csf1r", "Psap", "Cd74", "Efhd2Pld4", "xcl13", "lfngR1",
        "Fizz-1", "Mrc-1"
    ],
    "Sensory Satelite Glial cells": [
        "Bcan", "Fdps", "Mlc1", "Gja1", "Ednrb", "Slc1a3", "lfit1", "lfit3",
        "Gbp2", "Fabp7", "Bcan", "Fbln2", "Fbln5", "Kcnj10", "Cdh19", "Trpm3",
        "Slc12a2", "Stat3", "Mapk3", "Gja1", "Cxcr4", "Col28a1", "Adamts5", "Bcan",
        "Fbln2", "Sdc3"
    ],
    "General resident SGC": ["Scn7a", "Kcna1", "Anxa1"],
    "Sympathetic Satelite glial cell": ["Lipg", "Scd2", "Acsbg1", "Naaa"],
    "Schwann cell": [
        "Art3", "Gpm6b", "Pmp22", "Kcna1", "Plp1", "Fxyd1", "Prnp", "Matn2", "Cryab",
        "Cadm4", "Csrp1", "pr37", "DbiCnn3", "Cd9", "Sox10", "MbpMpz", "Ncmap", "Mag",
        "Mog", "Fabp5", "Fabp7"
    ],
    "Myeloids Schwann cells": ["Kcna1", "Kcna2", "Cacna2d1", "Slc12a2"],
    "Non myeloids Schwann cells": ["Kcna1", "Kcna2", "Kcna6", "Scn7a", "Cacna2d1", "Slc12a2"],
    "Endothelial cells": [
        "Fabp4", "Aqp7", "Scgb3a1", "Nkx2-3", "Oit3", "Star", "Pglyrp1", "Lcn2", "Lgfbp5",
        "Tmem100", "Fbln5", "lgfbp4", "Bmx", "Bgn", "Stmn2", "Alpl", "Gkn3", "Rad54b",
        "Car4", "Tmsb10", "Slc22a8", "Slc16a1", "SIc39a1", "Ttyh2", "Alkbh5", "Pam", "Vwf",
        "Icam1", "Vcam1", "Irf1"
    ]
}

print(cell_type_markers)
# Out:
# [Executed on 2023-09-20 14:49:56.069532]
# ...

# %%
# save the dictionary
import pickle

with open('cell_type_markers.pickle', 'wb') as handle:
    pickle.dump(cell_type_markers, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# [Executed on 2023-09-20 15:11:43.393711]

# %%
adata_gene=adata.var_names.tolist()

# %%
import scanpy as sc
# Out:
# [Executed on 2023-09-20 14:55:16.512216]

# %%
adata=sc.read_h5ad("/proj/sensoryaging/data/data/up_dated_data/SGNs/final_with_neuronIII.h5ad")
adata
# Out:
# [Executed on 2023-09-18 10:43:27.965046]
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 3295 × 33241
#     obs: 'sample_ID_Plate', 'batch', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden', 'doublet_scores', 'predicted_doublets', 'sex', 'leiden_sub', 'leiden_new', 'leiden_old', 'leiden_0'
#     uns: 'leiden_colors'
#     obsm: 'X_pca', 'X_umap', 'X_umapOriginal'
#     layers: 'Scale', 'log1p', 'umi'

# %%
sc.pl.umap(adata,color='leiden_old')
# Out:
# [Executed on 2023-09-18 10:43:30.380170]
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pp.highly_variable_genes(adata, n_top_genes=2000, flavor='seurat_v3',layer='umi')
# Out:
# [Executed on 2023-09-18 10:43:30.581769]

# %%
adata
# Out:
# [Executed on 2023-09-18 10:43:35.597630]
# AnnData object with n_obs × n_vars = 3295 × 33241
#     obs: 'sample_ID_Plate', 'batch', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden', 'doublet_scores', 'predicted_doublets', 'sex', 'leiden_sub', 'leiden_new', 'leiden_old', 'leiden_0'
#     var: 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'leiden_colors', 'leiden_old_colors', 'hvg'
#     obsm: 'X_pca', 'X_umap', 'X_umapOriginal'
#     layers: 'Scale', 'log1p', 'umi'

# %%
sc.pp.neighbors(adata, n_neighbors=30, n_pcs=25)
# Out:
# [Executed on 2023-09-18 10:43:35.655226]

# %%
sc.tl.leiden(adata,resolution=0.5,key_added='leiden_2')
sc.pl.umap(adata,color='leiden_2')
# Out:
# [Executed on 2023-09-18 10:43:36.268363]
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata,color=['leiden','leiden_old','leiden_new','leiden_2'])
# Out:
# [Executed on 2023-09-18 10:43:37.236878]
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata.obs['leiden'].value_counts()
# Out:
# [Executed on 2023-09-18 10:43:38.778760]
# leiden
# Schwann_cell              564
# Schwann_cell_2            445
# Osteoblasts               370
# Satelite/Schwann          306
# Unknown                   249
# Chondrocytes              204
# Neurons                   183
# Neurons_2                 130
# Glial_cell                129
# Satelite/Glial_cell       122
# Satelite_unknown           93
# Osteoclasts_2              91
# Maybe_Satelite             78
# Unknown_satelite/Glial     63
# 0                          55
# 1                          54
# Unknown_2                  41
# Endothelial                40
# Neuron_3                   28
# Immune_cell                22
# 2                          20
# 3                           8
# Name: count, dtype: int64

# %%
import anndata

# Assuming `adata` is your AnnData object

# Create a mask for cells you want to keep
mask = ~adata.obs['leiden'].isin(["Neuron_3", "Neurons_2", "Neurons"])

# Filter the AnnData object using the mask
adata = adata[mask]
# Out:
# [Executed on 2023-09-18 10:43:38.832774]

# %%
adata
# Out:
# [Executed on 2023-09-18 10:44:05.032668]
# View of AnnData object with n_obs × n_vars = 2954 × 33241
#     obs: 'sample_ID_Plate', 'batch', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden', 'doublet_scores', 'predicted_doublets', 'sex', 'leiden_sub', 'leiden_new', 'leiden_old', 'leiden_0', 'leiden_2'
#     var: 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'leiden_colors', 'leiden_old_colors', 'hvg', 'neighbors', 'leiden', 'leiden_2_colors', 'leiden_new_colors'
#     obsm: 'X_pca', 'X_umap', 'X_umapOriginal'
#     layers: 'Scale', 'log1p', 'umi'
#     obsp: 'distances', 'connectivities'

# %%
sc.pl.umap(adata,color=['leiden_new'])
# Out:
# [Executed on 2023-09-18 10:45:03.043140]
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata,color=['leiden'],legend_loc='on data')
# Out:
# [Executed on 2023-09-18 10:45:31.345074]
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata.write_h5ad("/proj/sensoryaging/data/data/up_dated_data/SGNs/final_with_neuronIV.h5ad")
# Out:
# [Executed on 2023-09-18 10:50:39.763815]

# %%
del adata.obs['leiden_sub']
# Out:
# [Executed on 2023-09-18 10:44:49.725950]

# %%
sc.pl.umap(adata,color=['leiden_2','leiden_old','leiden'],legend_loc='on data')
# Out:
# [Executed on 2023-09-18 10:58:19.398088]
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.tl.rank_genes_groups(adata, 'leiden_2', method='t-test')
sc.pl.rank_genes_groups(adata, n_genes=25, sharey=False)

# %%
import pandas as pd
#convert marker genes to dataframe
marker_genes=adata.uns['rank_genes_groups']['names']
marker_genes=pd.DataFrame(marker_genes)
marker_genes.head(20)
# Out:
# [Executed on 2023-09-18 10:48:36.413787]
#            0         1        2         3              4           5  \
# 0        Mpz  Adamts12    Pde1c   Ranbp3l           Bnc2     Slc24a2
# 1       Hcn1     Cped1  Slc6a15  Slc6a20a          Foxp2        Plp1
# 2      Mctp1     Ntrk3    Lama1     Trpm3          Cped1  St6galnac3
# 3       Utrn   Slc6a13    Npas3    Atp1a2          Klf12       Prr5l
# 4    Fam178b     Sned1    Trpm3   Slc6a13          Dock5      Ctnna2
# 5   Arhgap24     Cemip    Lrrc7    Prkag2           Msi2       Enpp2
# 6     Sorcs1    Zbtb20    Slit3    Adam12           Eya2   Mir219a-2
# 7         Qk     Kcnt1    Mpzl1     Ptgds           Ank2         Mog
# 8       Art3  Mir100hg    Hdac9   Slc22a8          Cald1         Mbp
# 9       Il16     Tmtc4   Cacnb4     Dock6          Foxp1       Edil3
# 10     Gfra1      Apod    Sgms1      Eya1          Tmtc1         Mag
# 11     Pmp22      Gjb6    Plcb4     Kcnt1        Pitpnc1        Map7
# ...

# %%
del adata.layers['log1p']
del adata.layers['Scale']

adata.X = adata.layers['umi'].copy()
sc.pp.normalize_total(adata, target_sum=None)
sc.pp.log1p(adata)
adata.layers['log1p'] = adata.X.copy()
sc.pp.scale(adata, max_value=10)
adata.layers['Scale'] = adata.X.copy()
# Out:
# [Executed on 2023-09-18 10:50:30.144209]

# %%
sc.pl.umap(adata,color=['leiden_2'],layer='log1p',legend_loc='on data')
# Out:
# [Executed on 2023-09-18 11:18:54.920389]
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata,color=['leiden_2','Cdh5','Tie1','Robo4'],layer='Scale',legend_loc='on data')
# Out:
# [Executed on 2023-09-18 11:26:33.969715]
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
endothelial=adata[adata.obs['leiden_2']=='13']
endothelial
# Out:
# [Executed on 2023-09-18 11:30:38.441150]
# View of AnnData object with n_obs × n_vars = 57 × 33241
#     obs: 'sample_ID_Plate', 'batch', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden', 'doublet_scores', 'predicted_doublets', 'sex', 'leiden_new', 'leiden_old', 'leiden_0', 'leiden_2'
#     var: 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'leiden_colors', 'leiden_old_colors', 'hvg', 'neighbors', 'leiden', 'leiden_2_colors', 'leiden_new_colors', 'leiden_sub_colors', 'rank_genes_groups', 'log1p'
#     obsm: 'X_pca', 'X_umap', 'X_umapOriginal'
#     layers: 'umi', 'log1p', 'Scale'
#     obsp: 'distances', 'connectivities'

# %%
sc.pp.neighbors(endothelial, n_neighbors=5, n_pcs=10)

sc.tl.leiden(endothelial,resolution=0.8)

sc.tl.umap(endothelial,min_dist=0.5)

sc.pl.umap(endothelial,color=['leiden'],layer='log1p')
# Out:
# [Executed on 2023-09-18 11:30:38.558445]
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.tl.rank_genes_groups(endothelial, 'leiden', method='t-test')
sc.pl.rank_genes_groups(endothelial, n_genes=25, sharey=False)
# Out:
# [Executed on 2023-09-18 11:30:40.200040]
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(

# %%
endothelial
# Out:
# [Executed on 2023-09-18 11:30:41.465017]
# AnnData object with n_obs × n_vars = 57 × 33241
#     obs: 'sample_ID_Plate', 'batch', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden', 'doublet_scores', 'predicted_doublets', 'sex', 'leiden_new', 'leiden_old', 'leiden_0', 'leiden_2'
#     var: 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'leiden_colors', 'leiden_old_colors', 'hvg', 'neighbors', 'leiden', 'leiden_2_colors', 'leiden_new_colors', 'leiden_sub_colors', 'rank_genes_groups', 'log1p', 'umap'
#     obsm: 'X_pca', 'X_umap', 'X_umapOriginal'
#     layers: 'umi', 'log1p', 'Scale'
#     obsp: 'distances', 'connectivities'

# %%
import pandas as pd
#convert marker genes to dataframe
endothelial_table=endothelial.uns['rank_genes_groups']['names']
endothelial_table=pd.DataFrame(endothelial_table)
endothelial_table.head(20)
# Out:
# [Executed on 2023-09-18 11:32:46.915434]
#            0         1           2         3
# 0      Egfl7   Cacna1c       Mecom    Adgrl4
# 1      Cgnl1     Irag1       Cyyr1     Robo4
# 2     Abcb1a     Myo1b      Sorbs2   Slco1c1
# 3      Stox2      Sox5        Flt1     Epas1
# 4       Glul     Plce1  St6galnac3   Slco1a4
# 5      Cldn5  Slc38a11        Tjp1      Jcad
# 6      Psma3  Arhgap42     Slco1a4  Slc39a10
# 7    Gm14303     Lama2        Eogt    Ablim1
# 8      Bcar1    Pdgfrb     Rundc3b     Tmtc2
# 9      Dctn4     Trpc3      Tspan5    Spock2
# 10     Tshz2    Inpp4b       Foxp1    Adgrf5
# 11      Ttc3     Daam2    Ralgapa1     Bmpr2
# 12     Cyb5b    Notch3       Abcc4     Prkch
# 13     Uqcc2     Pde3a      Atp10a    Gpcpd1
# 14     Rbm34     Carmn     Adipor2   St3gal6
# 15   Gm14279      Dlc1        Lef1       Erg
# 16      Gbp4     Plcl1      Adgrl4     Esyt2
# 17    Pla2g6     Abcc9       Ptprm    Pecam1
# 18  Slc22a17   Colec12        Tet3    Clec2d
# ...

# %%
sc.pl.umap(endothelial,color=['leiden','Cacna1c','Irag1','Myo1b','Sox5'],layer='Scale',legend_loc='on data')
# Out:
# [Executed on 2023-09-18 11:33:59.758044]
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(endothelial,color=['leiden','Adgrl4','Robo4','Slco1c1','Epas1'],layer='Scale',legend_loc='on data')
# Out:
# [Executed on 2023-09-18 11:51:45.972552]
# /proj/sensoryaging/.conda/env/scvi-env/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
